# %% [markdown]
# 1、插入数据

# %%
import psycopg2
import struct
import os

# 1. 设置 PostgreSQL 连接
def create_connection():
    try:
        conn = psycopg2.connect(
            database="vectordb",
            user="vectordb",
            host="172.17.0.2",  # depend on your own docker container ip
            port="5432"
        )
        return conn
    except Exception as e:
        print(f"连接数据库失败: {e}")
        return None

# 2. 批量插入数据
def insert_data(conn, batch_data):
    try:
        cursor = conn.cursor()
        # 假设数据库表中有足够的列来接收 col_1 到 col_19
        insert_query = "INSERT INTO enron_label (id, image_embedding, col_1, col_2, col_3, col_4, col_5, col_6, col_7, col_8, col_9, col_10, col_11, col_12, col_13, col_14, col_15, col_16, col_17,col_18, col_19) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
        cursor.executemany(insert_query, batch_data)
        conn.commit()
        print(f"成功插入 {len(batch_data)} 条数据！")
        cursor.close()
    except Exception as e:
        print(f"插入数据时出错: {e}")

# 3. 读取文件并分批插入数据
def load_and_insert_data(vector_file_path, label_file_path):
    # 打开向量文件和标签文件
    with open(vector_file_path, "rb") as vector_file, open(label_file_path, "r") as label_file:
        batch_data = []
        id_counter = 1  # id 从 1 开始自增
        batch_size = 1000  # 每批次插入1000条数据

        # 创建数据库连接
        conn = create_connection()
        if not conn:
            print("无法连接到数据库，终止操作。")
            return

        # 不再跳过第一行
        for label_line in label_file:
            # 读取向量数据
            dim_bytes = vector_file.read(4)
            if not dim_bytes:
                break  # 文件结束
            dim = struct.unpack('i', dim_bytes)[0]
            vector = struct.unpack('f' * dim, vector_file.read(4 * dim))

            # 解析标签行
            label_values = label_line.strip().split()
            if len(label_values) != 19:
                print(f"警告：标签行中数据数量不正确（应为19个），实际数量为 {len(label_values)}。跳过该行。")
                continue

            # 将解析后的数据追加到批量数据列表
            batch_data.append((id_counter, list(vector), *label_values))

            # 检查是否达到批量大小，如果是，则插入数据库并清空批量数据列表
            if len(batch_data) == batch_size:
                insert_data(conn, batch_data)
                batch_data = []

            id_counter += 1

        # 插入剩余的批量数据
        if batch_data:
            insert_data(conn, batch_data)

        conn.close()  # 关闭数据库连接

ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), "../../../data/Experiment"))
# 4. 执行数据加载和插入
vector_file_path = os.path.join(ROOT_DIR, "labelfilterData/datasets/enron/enron_base.fvecs")
label_file_path = os.path.join(ROOT_DIR, "labelfilterData/labels/enron/labels_with_selectivity.txt")
load_and_insert_data(vector_file_path, label_file_path)

print("数据导入完成。")

# %% [markdown]
# 2、构建索引并计算索引构建时间

# %%
import psycopg2
from psycopg2 import OperationalError
import time

def create_connection():
    conn = None
    try:
        conn = psycopg2.connect(
            database="vectordb",
            user="vectordb",
            host="172.17.0.2",
            port="5432"
        )
        print("连接成功！")
    except OperationalError as e:
        print(f"连接失败: {e}")
    return conn

# 执行索引构建SQL
def create_index(conn):
    cursor = conn.cursor()
    try:

        # 记录开始时间
        start_time = time.time()

        # 执行索引构建
        create_index_sql = """
            CREATE INDEX vbase_enron_16_200
            ON enron_label
            USING hnsw(image_embedding)
            WITH (
                dimension = 1369,
                distmethod = 'l2_distance'
            );
        """
        cursor.execute(create_index_sql)
        conn.commit()  

        end_time = time.time()
        index_build_time = end_time - start_time

        return index_build_time
    except Exception as e:
        print(f"索引构建失败: {e}")
    finally:
        cursor.close()

def main():
    connection = create_connection()

    if connection:
        try:
            create_index(connection)
        finally:
            connection.close()
if __name__ == "__main__":
    main()
# Out:
# 连接成功！

# %% [markdown]
# 3、脚本单线程测试

# %%
import psycopg2
import struct
import time
import os

# 1. 设置 PostgreSQL 连接
def create_connection():
    try:
        conn = psycopg2.connect(
            database="vectordb",
            user="vectordb",
            host="172.17.0.2",  # 你的数据库主机
            port="5432"
        )
        return conn
    except Exception as e:
        print(f"连接数据库失败: {e}")
        return None
    
def read_fvecs_file(file_path):
    """读取 .fvecs 文件并返回所有向量"""
    query_vectors = []
    with open(file_path, "rb") as f:
        while True:
            # 读取向量维度
            dim_bytes = f.read(4)
            if not dim_bytes:
                break
            dim = struct.unpack('i', dim_bytes)[0]
            # 读取向量数据
            vector_bytes = f.read(dim * 4)
            if not vector_bytes:
                break
            vector = struct.unpack(f'{dim}f', vector_bytes)
            query_vectors.append(vector)
    return query_vectors
def read_txt_file(file_path):
    """读取 .txt 文件并返回查询条件列表"""
    conditions = []
    with open(file_path, "r") as f:
        lines = f.readlines()
        lines = lines[1:]  # 跳过第一行
        for line in lines:
            line = line.strip()
            if line:  # 跳过空行
                # 用空格分割，保留所有值作为条件
                parts = line.split()
                conditions.append(parts)  # 存储所有条件的值
    return conditions
def execute_query(conn, query, params, output_file, j_value, total_time, k):
    cursor = conn.cursor()
    try:
        cursor.execute("SET enable_seqscan = off;")  # 设置索引扫描
        cursor.execute("SET enable_indexscan = on;")  # 设置索引扫描
        cursor.execute(f"SET hnsw.ef_search = {j_value};")  # 设置索引扫描
        # 设置索引扫描和关闭顺序扫描
        start_time = time.time()  # 开始计时
        # 执行查询
        cursor.execute(query, params)
        result = cursor.fetchall()  # 获取查询结果
        end_time = time.time()  # 结束计时
        print(f"查询执行时间: {end_time - start_time:.6f} 秒")
        if k!= 0:
            total_time += (end_time - start_time)  # 累加查询时间

        # 将查询结果写入文件
        with open(output_file, "a") as f:
            ids = [str(row[0] - 1) for row in result]  # 提取 ID 列
            f.write(" ".join(ids) + "\n")  # 每次查询结果写在一行
    except Exception as e:
        print(f"查询失败: {e}")
    finally:
        cursor.close()
    return total_time
def main():
    ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), "../../../data/Experiment"))
    # 文件路径
    fvecs_file = os.path.join(ROOT_DIR, "labelfilterData/datasets/enron/enron_query.fvecs")

    list_1 = ["1", "3_1", "3_2", "3_3", "3_4", "4", "5_1", "5_2", "5_3", "5_4", "6", "7_1", "7_2", "7_3", "7_4"]
    list_2 = [["col_1"], ["col_16"], ["col_17"], ["col_18"], ["col_19"], ["col_8"], ["col_2"], ["col_3"], ["col_5"], ["col_1"], ["col_1", "col_9", "col_10"],["col_1", "col_9", "col_16"],["col_1", "col_9", "col_17"],["col_1", "col_9", "col_18"],["col_1", "col_9", "col_19"]]
    list_3 = [86, 150, 250, 400]

    # 读取向量数据和查询条件
    query_vectors = read_fvecs_file(fvecs_file)
   
    for i, i_value in enumerate(list_1):
        for j_value in list_3:
            # 创建数据库连接
            connection = create_connection()
            if connection:
                try:
                    txt_file = os.path.join(ROOT_DIR, f"labelfilterData/query_label/enron/{i_value}.txt")
                    output_file = os.path.join(os.getcwd(), "result", f"{i_value}_16_200_{j_value}.out")
                    conditions = read_txt_file(txt_file)
                    # 清空结果文件，确保每次执行时写入的是最新的查询结果
                    with open(output_file, "w") as f:
                        f.truncate(0)

                        # 定义数据库表的列名，与条件对应
                        columns = list_2[i]
                        total_time = 0
                        # 遍历查询条件
                        for k in range(len(conditions)):
                            condition_values = conditions[k]
                            query_vector = query_vectors[k]
                            # 构造 SQL 查询语句
                            # 动态生成 WHERE 条件
                            if len(condition_values) == 1:
                                conditions_sql = f"{columns[0]} = %s"
                            else:
                                conditions_sql = " AND ".join([f"{col} = %s" for col in columns[:len(condition_values)]])
                            query = f"""
                                SELECT id
                                FROM enron_label
                                WHERE {conditions_sql}
                                ORDER BY image_embedding <-> ARRAY[{', '.join(map(str, query_vector))}]
                                LIMIT 10;
                            """
                            print(f"正在执行查询条件: {condition_values}...")
                            total_time = execute_query(connection, query, tuple(condition_values), output_file, j_value, total_time, k)
                        qps = len(query_vectors) / total_time if total_time != 0 else 0
                        # 将 QPS 写入 output_file
                        with open(output_file, "a") as f:  # 使用追加模式
                            f.write(f"\nQPS: {qps}\n")
                finally:
                    connection.close()
    
if __name__ == "__main__":
    main()
# Out:
# 正在执行查询条件: ['14']...
# 查询执行时间: 4.253622 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.314850 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.214809 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.246283 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.223130 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.140373 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.085724 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.127253 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.119383 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.176812 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.100159 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.094905 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.091719 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.082072 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.094887 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.079653 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.090656 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.089028 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.076886 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.062195 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.038751 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.074249 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.024488 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.050843 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.017124 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.009853 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.061656 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.089792 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.009489 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.029085 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.023009 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.066820 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.073783 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.018697 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.007145 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.011232 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.029414 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.028132 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.004221 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.004647 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.005856 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.024438 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.069574 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.004588 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.005720 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.003716 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.005119 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.030248 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.021747 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.019778 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.041454 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.005390 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.004878 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.004973 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.004239 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.001839 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.028214 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.026222 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.006537 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.003014 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.004400 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.003847 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.020377 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.004014 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.005879 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.003964 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.003817 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.004193 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.004477 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.004203 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.002320 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.003474 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.004189 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.001981 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.002482 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.004125 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.003411 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.003184 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.003496 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.003232 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.002302 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.022604 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.004533 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.017116 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.004203 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.004367 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.011580 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.004532 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.003878 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.002640 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.002317 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.019140 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.003022 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.004081 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.003110 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.002337 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.003423 秒
# 正在执行查询条件: ['13']...
# 查询执行时间: 0.002554 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.001937 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.001456 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.002938 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.002773 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.003022 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.003018 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.003888 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.001816 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.002114 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.002258 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.002852 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.002631 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.003056 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.003137 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.002942 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.003732 秒
# 正在执行查询条件: ['9']...
# 查询执行时间: 0.002191 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.002032 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.003220 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.002727 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.003097 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.001916 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.002308 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.003941 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.002552 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.003044 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.002471 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.002181 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.003356 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.002115 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.048430 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.004183 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.002456 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.002408 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.002887 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.002587 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.002503 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.003236 秒
# 正在执行查询条件: ['12']...
# 查询执行时间: 0.003096 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.002445 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.002875 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.002315 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.002059 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.002482 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.002818 秒
# 正在执行查询条件: ['3']...
# 查询执行时间: 0.002403 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.002637 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.001741 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.002866 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.003845 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.003201 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.002408 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.002372 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.001596 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.001766 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.001947 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.002573 秒
# 正在执行查询条件: ['15']...
# 查询执行时间: 0.002729 秒
# 正在执行查询条件: ['14']...
# 查询执行时间: 0.002301 秒
# 正在执行查询条件: ['11']...
# 查询执行时间: 0.001900 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.002958 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.002532 秒
# 正在执行查询条件: ['8']...
# 查询执行时间: 0.002115 秒
# 正在执行查询条件: ['5']...
# 查询执行时间: 0.001917 秒
# 正在执行查询条件: ['7']...
# 查询执行时间: 0.002213 秒
# 正在执行查询条件: ['2']...
# 查询执行时间: 0.001781 秒
# 正在执行查询条件: ['6']...
# 查询执行时间: 0.001754 秒
# 正在执行查询条件: ['1']...
# 查询执行时间: 0.002248 秒
# 正在执行查询条件: ['10']...
# 查询执行时间: 0.002759 秒
# 正在执行查询条件: ['4']...
# 查询执行时间: 0.
# 正在执行查询条件: ['3', '904', '7501']...
# 查询执行时间: 0.004315 秒
# 正在执行查询条件: ['10', '910', '7501']...
# 查询执行时间: 0.008378 秒
# 正在执行查询条件: ['5', '906', '7501']...
# 查询执行时间: 0.012358 秒
# 正在执行查询条件: ['14', '903', '7501']...
# 查询执行时间: 0.007646 秒
# 正在执行查询条件: ['3', '908', '7501']...
# 查询执行时间: 0.008690 秒
# 正在执行查询条件: ['9', '910', '7501']...
# 查询执行时间: 0.007941 秒
# 正在执行查询条件: ['11', '901', '7501']...
# 查询执行时间: 0.010076 秒
# 正在执行查询条件: ['9', '901', '7501']...
# 查询执行时间: 0.007032 秒
# 正在执行查询条件: ['13', '908', '7501']...
# 查询执行时间: 0.015599 秒
# 正在执行查询条件: ['5', '906', '7501']...
# 查询执行时间: 0.008315 秒
# 正在执行查询条件: ['15', '902', '7501']...
# 查询执行时间: 0.006211 秒
# 正在执行查询条件: ['11', '909', '7501']...
# 查询执行时间: 0.009882 秒
# 正在执行查询条件: ['3', '906', '7501']...
# 查询执行时间: 0.009032 秒
# 正在执行查询条件: ['6', '906', '7501']...
# 查询执行时间: 0.008069 秒
# 正在执行查询条件: ['9', '905', '7501']...
# 查询执行时间: 0.009341 秒
# 正在执行查询条件: ['1', '903', '7501']...
# 查询执行时间: 0.008232 秒
# 正在执行查询条件: ['4', '908', '7501']...
# 查询执行时间: 0.011305 秒
# 正在执行查询条件: ['15', '903', '7501']...
# 查询执行时间: 0.006668 秒
# 正在执行查询条件: ['4', '905', '7501']...
# 查询执行时间: 0.008290 秒
# 正在执行查询条件: ['13', '904', '7501']...
# 查询执行时间: 0.011120 秒
# 正在执行查询条件: ['1', '907', '7501']...
# 查询执行时间: 0.008784 秒
# 正在执行查询条件: ['13', '902', '7501']...
# 查询执行时间: 0.012389 秒
# 正在执行查询条件: ['8', '902', '7501']...
# 查询执行时间: 0.009848 秒
# 正在执行查询条件: ['5', '909', '7501']...
# 查询执行时间: 0.009207 秒
# 正在执行查询条件: ['1', '905', '7501']...
# 查询执行时间: 0.006749 秒
# 正在执行查询条件: ['11', '901', '7501']...
# 查询执行时间: 0.010257 秒
# 正在执行查询条件: ['6', '901', '7501']...
# 查询执行时间: 0.009665 秒
# 正在执行查询条件: ['4', '905', '7501']...
# 查询执行时间: 0.006046 秒
# 正在执行查询条件: ['12', '909', '7501']...
# 查询执行时间: 0.014936 秒
# 正在执行查询条件: ['7', '907', '7501']...
# 查询执行时间: 0.011096 秒
# 正在执行查询条件: ['5', '904', '7501']...
# 查询执行时间: 0.009451 秒
# 正在执行查询条件: ['3', '901', '7501']...
# 查询执行时间: 0.006761 秒
# 正在执行查询条件: ['3', '909', '7501']...
# 查询执行时间: 0.013771 秒
# 正在执行查询条件: ['9', '906', '7501']...
# 查询执行时间: 0.010593 秒
# 正在执行查询条件: ['8', '901', '7501']...
# 查询执行时间: 0.006954 秒
# 正在执行查询条件: ['2', '904', '7501']...
# 查询执行时间: 0.007239 秒
# 正在执行查询条件: ['8', '908', '7501']...
# 查询执行时间: 0.013500 秒
# 正在执行查询条件: ['9', '904', '7501']...
# 查询执行时间: 0.008879 秒
# 正在执行查询条件: ['14', '904', '7501']...
# 查询执行时间: 0.009517 秒
# 正在执行查询条件: ['8', '910', '7501']...
# 查询执行时间: 0.009415 秒
# 正在执行查询条件: ['9', '907', '7501']...
# 查询执行时间: 0.009226 秒
# 正在执行查询条件: ['14', '905', '7501']...
# 查询执行时间: 0.009087 秒
# 正在执行查询条件: ['2', '902', '7501']...
# 查询执行时间: 0.012745 秒
# 正在执行查询条件: ['7', '905', '7501']...
# 查询执行时间: 0.005837 秒
# 正在执行查询条件: ['5', '904', '7501']...
# 查询执行时间: 0.009419 秒
# 正在执行查询条件: ['1', '903', '7501']...
# 查询执行时间: 0.013349 秒
# 正在执行查询条件: ['4', '905', '7501']...
# 查询执行时间: 0.008641 秒
# 正在执行查询条件: ['12', '909', '7501']...
# 查询执行时间: 0.007024 秒
# 正在执行查询条件: ['12', '907', '7501']...
# 查询执行时间: 0.007422 秒
# 正在执行查询条件: ['1', '908', '7501']...
# 查询执行时间: 0.011190 秒
# 正在执行查询条件: ['10', '906', '7501']...
# 查询执行时间: 0.011735 秒
# 正在执行查询条件: ['9', '906', '7501']...
# 查询执行时间: 0.008975 秒
# 正在执行查询条件: ['5', '908', '7501']...
# 查询执行时间: 0.010444 秒
# 正在执行查询条件: ['1', '905', '7501']...
# 查询执行时间: 0.014567 秒
# 正在执行查询条件: ['12', '909', '7501']...
# 查询执行时间: 0.005423 秒
# 正在执行查询条件: ['9', '903', '7501']...
# 查询执行时间: 0.011527 秒
# 正在执行查询条件: ['13', '906', '7501']...
# 查询执行时间: 0.012064 秒
# 正在执行查询条件: ['11', '910', '7501']...
# 查询执行时间: 0.010895 秒
# 正在执行查询条件: ['12', '907', '7501']...
# 查询执行时间: 0.012136 秒
# 正在执行查询条件: ['11', '903', '7501']...
# 查询执行时间: 0.016235 秒
# 正在执行查询条件: ['10', '904', '7501']...
# 查询执行时间: 0.005219 秒
# 正在执行查询条件: ['14', '901', '7501']...
# 查询执行时间: 0.010010 秒
# 正在执行查询条件: ['14', '901', '7501']...
# 查询执行时间: 0.015716 秒
# 正在执行查询条件: ['7', '903', '7501']...
# 查询执行时间: 0.005876 秒
# 正在执行查询条件: ['15', '908', '7501']...
# 查询执行时间: 0.005942 秒
# 正在执行查询条件: ['4', '907', '7501']...
# 查询执行时间: 0.004734 秒
# 正在执行查询条件: ['13', '908', '7501']...
# 查询执行时间: 0.009905 秒
# 正在执行查询条件: ['1', '902', '7501']...
# 查询执行时间: 0.011218 秒
# 正在执行查询条件: ['1', '901', '7501']...
# 查询执行时间: 0.004214 秒
# 正在执行查询条件: ['4', '903', '7501']...
# 查询执行时间: 0.009094 秒
# 正在执行查询条件: ['5', '902', '7501']...
# 查询执行时间: 0.464909 秒
# 正在执行查询条件: ['9', '904', '7501']...
# 查询执行时间: 0.008461 秒
# 正在执行查询条件: ['8', '909', '7501']...
# 查询执行时间: 0.009127 秒
# 正在执行查询条件: ['11', '904', '7501']...
# 查询执行时间: 0.010223 秒
# 正在执行查询条件: ['1', '909', '7501']...
# 查询执行时间: 0.007761 秒
# 正在执行查询条件: ['14', '906', '7501']...
# 查询执行时间: 0.007734 秒
# 正在执行查询条件: ['6', '901', '7501']...
# 查询执行时间: 0.012636 秒
# 正在执行查询条件: ['10', '906', '7501']...
# 查询执行时间: 0.012983 秒
# 正在执行查询条件: ['11', '909', '7501']...
# 查询执行时间: 0.009911 秒
# 正在执行查询条件: ['10', '907', '7501']...
# 查询执行时间: 0.007704 秒
# 正在执行查询条件: ['6', '901', '7501']...
# 查询执行时间: 0.016821 秒
# 正在执行查询条件: ['1', '907', '7501']...
# 查询执行时间: 0.014264 秒
# 正在执行查询条件: ['9', '908', '7501']...
# 查询执行时间: 0.009229 秒
# 正在执行查询条件: ['10', '904', '7501']...
# 查询执行时间: 0.010055 秒
# 正在执行查询条件: ['7', '903', '7501']...
# 查询执行时间: 0.010206 秒
# 正在执行查询条件: ['5', '906', '7501']...
# 查询执行时间: 0.009442 秒
# 正在执行查询条件: ['4', '901', '7501']...
# 查询执行时间: 0.009497 秒
# 正在执行查询条件: ['9', '904', '7501']...
# 查询执行时间: 0.008469 秒
# 正在执行查询条件: ['10', '903', '7501']...
# 查询执行时间: 0.014753 秒
# 正在执行查询条件: ['4', '901', '7501']...
# 查询执行时间: 0.008699 秒
# 正在执行查询条件: ['13', '907', '7501']...
# 查询执行时间: 0.010037 秒
# 正在执行查询条件: ['13', '908', '7501']...
# 查询执行时间: 0.010922 秒
# 正在执行查询条件: ['3', '905', '7501']...
# 查询执行时间: 0.009526 秒
# 正在执行查询条件: ['13', '901', '7501']...
# 查询执行时间: 0.008143 秒
# 正在执行查询条件: ['11', '902', '7501']...
# 查询执行时间: 0.010428 秒
# 正在执行查询条件: ['14', '907', '7501']...
# 查询执行时间: 0.010805 秒
# 正在执行查询条件: ['12', '910', '7501']...
# 查询执行时间: 0.007602 秒
# 正在执行查询条件: ['3', '909', '7501']...
# 查询执行时间: 0.012640 秒
# 正在执行查询条件: ['15', '909', '7501']...
# 查询执行时间: 0.004845 秒
# 正在执行查询条件: ['8', '907', '7501']...
# 查询执行时间: 0.009546 秒
# 正在执行查询条件: ['13', '906', '7501']...
# 查询执行时间: 0.012527 秒
# 正在执行查询条件: ['15', '903', '7501']...
# 查询执行时间: 0.007523 秒
# 正在执行查询条件: ['15', '905', '7501']...
# 查询执行时间: 0.009276 秒
# 正在执行查询条件: ['10', '905', '7501']...
# 查询执行时间: 0.006765 秒
# 正在执行查询条件: ['13', '909', '7501']...
# 查询执行时间: 0.007950 秒
# 正在执行查询条件: ['9', '904', '7501']...
# 查询执行时间: 0.017245 秒
# 正在执行查询条件: ['15', '910', '7501']...
# 查询执行时间: 0.012365 秒
# 正在执行查询条件: ['7', '902', '7501']...
# 查询执行时间: 0.010124 秒
# 正在执行查询条件: ['2', '908', '7501']...
# 查询执行时间: 0.010983 秒
# 正在执行查询条件: ['12', '905', '7501']...
# 查询执行时间: 0.010975 秒
# 正在执行查询条件: ['14', '909', '7501']...
# 查询执行时间: 0.010414 秒
# 正在执行查询条件: ['3', '908', '7501']...
# 查询执行时间: 0.006057 秒
# 正在执行查询条件: ['7', '904', '7501']...
# 查询执行时间: 0.012019 秒
# 正在执行查询条件: ['13', '907', '7501']...
# 查询执行时间: 0.005978 秒
# 正在执行查询条件: ['12', '904', '7501']...
# 查询执行时间: 0.009386 秒
# 正在执行查询条件: ['8', '905', '7501']...
# 查询执行时间: 0.007161 秒
# 正在执行查询条件: ['9', '909', '7501']...
# 查询执行时间: 0.011950 秒
# 正在执行查询条件: ['7', '910', '7501']...
# 查询执行时间: 0.008023 秒
# 正在执行查询条件: ['7', '902', '7501']...
# 查询执行时间: 0.008739 秒
# 正在执行查询条件: ['6', '905', '7501']...
# 查询执行时间: 0.008149 秒
# 正在执行查询条件: ['8', '904', '7501']...
# 查询执行时间: 0.005825 秒
# 正在执行查询条件: ['5', '905', '7501']...
# 查询执行时间: 0.015063 秒
# 正在执行查询条件: ['4', '904', '7501']...
# 查询执行时间: 0.009136 秒
# 正在执行查询条件: ['14', '906', '7501']...
# 查询执行时间: 0.005394 秒
# 正在执行查询条件: ['9', '901', '7501']...
# 查询执行时间: 0.006924 秒
# 正在执行查询条件: ['14', '908', '7501']...
# 查询执行时间: 0.009509 秒
# 正在执行查询条件: ['1', '901', '7501']...
# 查询执行时间: 0.011191 秒
# 正在执行查询条件: ['4', '908', '7501']...
# 查询执行时间: 0.008337 秒
# 正在执行查询条件: ['7', '908', '7501']...
# 查询执行时间: 0.010192 秒
# 正在执行查询条件: ['12', '907', '7501']...
# 查询执行时间: 0.011493 秒
# 正在执行查询条件: ['10', '902', '7501']...
# 查询执行时间: 0.011836 秒
# 正在执行查询条件: ['1', '908', '7501']...
# 查询执行时间: 0.011215 秒
# 正在执行查询条件: ['8', '902', '7501']...
# 查询执行时间: 0.007007 秒
# 正在执行查询条件: ['6', '906', '7501']...
# 查询执行时间: 0.005097 秒
# 正在执行查询条件: ['15', '902', '7501']...
# 查询执行时间: 0.014931 秒
# 正在执行查询条件: ['7', '906', '7501']...
# 查询执行时间: 0.010832 秒
# 正在执行查询条件: ['11', '910', '7501']...
# 查询执行时间: 0.012613 秒
# 正在执行查询条件: ['5', '904', '7501']...
# 查询执行时间: 0.008859 秒
# 正在执行查询条件: ['9', '910', '7501']...
# 查询执行时间: 0.012080 秒
# 正在执行查询条件: ['1', '910', '7501']...
# 查询执行时间: 0.007419 秒
# 正在执行查询条件: ['11', '907', '7501']...
# 查询执行时间: 0.005712 秒
# 正在执行查询条件: ['13', '907', '7501']...
# 查询执行时间: 0.008807 秒
# 正在执行查询条件: ['5', '903', '7501']...
# 查询执行时间: 0.009115 秒
# 正在执行查询条件: ['15', '901', '7501']...
# 查询执行时间: 0.006878 秒
# 正在执行查询条件: ['5', '909', '7501']...
# 查询执行时间: 0.011323 秒
# 正在执行查询条件: ['5', '909', '7501']...
# 查询执行时间: 0.009613 秒
# 正在执行查询条件: ['2', '902', '7501']...
# 查询执行时间: 0.012922 秒
# 正在执行查询条件: ['4', '903', '7501']...
# 查询执行时间: 0.011192 秒
# 正在执行查询条件: ['2', '905', '7501']...
# 查询执行时间: 0.008718 秒
# 正在执行查询条件: ['6', '905', '7501']...
# 查询执行时间: 0.012430 秒
# 正在执行查询条件: ['9', '906', '7501']...
# 查询执行时间: 0.008857 秒
# 正在执行查询条件: ['4', '907', '7501']...
# 查询执行时间: 0.013081 秒
# 正在执行查询条件: ['4', '904', '7501']...
# 查询执行时间: 0.007950 秒
# 正在执行查询条件: ['2', '908', '7501']...
# 查询执行时间: 0.005412 秒
# 正在执行查询条件: ['14', '907', '7501']...
# 查询执行时间: 0.010937 秒
# 正在执行查询条件: ['4', '904', '7501']...
# 查询执行时间: 0.010356 秒
# 正在执行查询条件: ['8', '906', '7501']...
# 查询执行时间: 0.004741 秒
# 正在执行查询条件: ['1', '903', '7501']...
# 查询执行时间: 0.009461 秒
# 正在执行查询条件: ['3', '909', '7501']...
# 查询执行时间: 0.009068 秒
# 正在执行查询条件: ['7', '910', '7501']...
# 查询执行时间: 0.013218 秒
# 正在执行查询条件: ['4', '903', '7501']...
# 查询执行时间: 0.002843 秒
# 正在执行查询条件: ['3', '903', '7501']...
# 查询执行时间: 0.016270 秒
# 正在执行查询条件: ['13', '907', '7501']...
# 查询执行时间: 0.007298 秒
# 正在执行查询条件: ['6', '901', '7501']...
# 查询执行时间: 0.011412 秒
# 正在执行查询条件: ['11', '906', '7501']...
# 查询执行时间: 0.011162 秒
# 正在执行查询条件: ['8', '905', '7501']...
# 查询执行时间: 0.006258 秒
# 正在执行查询条件: ['11', '910', '7501']...
# 查询执行时间: 0.008909 秒
# 正在执行查询条件: ['15', '908', '7501']...
# 查询执行时间: 0.004627 秒
# 正在执行查询条件: ['1', '905', '7501']...
# 查询执行时间: 0.007413 秒
# 正在执行查询条件: ['5', '902', '7501']...
# 查询执行时间: 0.013407 秒
# 正在执行查询条件: ['5', '909', '7501']...
# 查询执行时间: 0.007560 秒
# 正在执行查询条件: ['11', '901', '7501']...
# 查询执行时间: 0.009820 秒
# 正在执行查询条件: ['7', '902', '7501']...
# 查询执行时间: 0.014892 秒
# 正在执行查询条件: ['7', '910', '7501']...
# 查询执行时间: 0.011375 秒
# 正在执行查询条件: ['15', '909', '7501']...
# 查询执行时间: 0.013259 秒
# 正在执行查询条件: ['13', '902', '7501']...
# 查询执行时间: 0.008186 秒
# 正在执行查询条件: ['12', '908', '7501']...
# 查询执行时间: 0.010950 秒
# 正在执行查询条件: ['12', '906', '7501']...
# 查询执行时间: 0.043309 秒
# 正在执行查询条件: ['5', '910', '7501']...
# 查询执行时间: 0.008722 秒
# 正在执行查询条件: ['12', '901', '7501']...
# 查询执行时间: 0.009105 秒
# 正在执行查询条件: ['6', '906', '7501']...
# 查询执行时间: 0.010904 秒
# 正在执行查询条件: ['8', '910', '7501']...
# 查询执行时间: 0.011259 秒
# 正在执行查询条件: ['5', '906', '7501']...
# 查询执行时间: 0.011204 秒
# 正在执行查询条件: ['5', '902', '7501']...
# 查询执行时间: 0.009356 秒
# 正在执行查询条件: ['2', '908', '7501']...
# 查询执行时间: 0.014447 秒
# 正在执行查询条件: ['15', '909', '7501']...
# 查询执行时间: 0.004129 秒
# 正在执行查询条件: ['1', '907', '7501']...
# 查询执行时间: 0.010875 秒
# 正在执行查询条件: ['3', '903', '7501']...
# 查询执行时间: 0.011293 秒
# 正在执行查询条件: ['10', '909', '7501']...
# 查询执行时间: 0.008468 秒
# 正在执行查询条件: ['15', '908', '7501']...
# 查询执行时间: 0.005889 秒
# 正在执行查询条件: ['4', '903', '7501']...
# 查询执行时间: 0.010362 秒
# 正在执行查询条件: ['4', '909', '7501']...
# 查询执行时间: 0.008679 秒
# 正在执行查询条件: ['7', '901', '7501']...
# 查询执行时间: 0.008801 秒
# 正在执行查询条件: ['1', '901', '7501']...
# 查询执行时间: 0.009458 秒
# 正在执行查询条件: ['9', '906', '7501']...
# 查询执行时间: 0.006640 秒
# 正在执行查询条件: ['11', '909', '7501']...
# 查询执行时间: 0.004826 秒
# 正在执行查询条件: ['6', '902', '7501']...
# 查询执行时间: 0.009841 秒
# 正在执行查询条件: ['8', '909', '7501']...
# 查询执行时间: 0.004257 秒
# 正在执行查询条件: ['3', '905', '7501']...
# 查询执行时间: 0.006509 秒
# 正在执行查询条件: ['10', '908', '7501']...
# 查询执行时间: 0.011562 秒
# 正在执行查询条件: ['3', '904', '7501']...
# 查询执行时间: 0.004599 秒
# 正在执行查询条件: ['10', '910', '7501']...
# 查询执行时间: 0.008604 秒
# 正在执行查询条件: ['5', '906', '7501']...
# 查询执行时间: 0.013110 秒
# 正在执行查询条件: ['14', '903', '7501']...
# 查询执行时间: 0.008034 秒
# 正在执行查询条件: ['3', '908', '7501']...
# 查询执行时间: 0.008937 秒
# 正在执行查询条件: ['9', '910', '7501']...
# 查询执行时间: 0.007882 秒
# 正在执行查询条件: ['11', '901', '7501']...
# 查询执行时间: 0.010373 秒
# 正在执行查询条件: ['9', '901', '7501']...
# 查询执行时间: 0.007261 秒
# 正在执行查询条件: ['13', '908', '7501']...
# 查询执行时间: 0.016292 秒
# 正在执行查询条件: ['5', '906', '7501']...
# 查询执行时间: 0.008446 秒
# 正在执行查询条件: ['15', '902', '7501']...
# 查询执行时间: 0.006784 秒
# 正在执行查询条件: ['11', '909', '7501']...
# 查询执行时间: 0.008615 秒
# 正在执行查询条件: ['3', '906', '7501']...
# 查询执行时间: 0.010071 秒
# 正在执行查询条件: ['6', '906', '7501']...
# 查询执行时间: 0.008274 秒
# 正在执行查询条件: ['9', '905', '7501']...
# 查询执行时间: 0.009729 秒
# 正在执行查询条件: ['1', '903', '7501']...
# 查询执行时间: 0.008483 秒
# 正在执行查询条件: ['4', '908', '7501']...
# 查询执行时间: 0.012353 秒
# 正在执行查询条件: ['15', '903', '7501']...
# 查询执行时间: 0.006873 秒
# 正在执行查询条件: ['4', '905', '7501']...
# 查询执行时间: 0.008980 秒
# 正在执行查询条件: ['13', '904', '7501']...
# 查询执行时间: 0.011494 秒
# 正在执行查询条件: ['1', '907', '7501']...
# 查询执行时间: 0.009239 秒
# 正在执行查询条件: ['13', '902', '7501']...
# 查询执行时间: 0.012711 秒
# 正在执行查询条件: ['8', '902', '7501']...
# 查询执行时间: 0.010144 秒
# 正在执行查询条件: ['5', '909', '7501']...
# 查询执行时间: 0.010277 秒
# 正在执行查询条件: ['1', '905', '7501']...
# 查询执行时间: 0.006939 秒
# 正在执行查询条件: ['11', '901', '7501']...
# 查询执行时间: 0.010767 秒
# 正在执行查询条件: ['6', '901', '7501']...
# 查询执行时间: 0.008597 秒
# 正在执行查询条件: ['4', '905', '7501']...
# 查询执行时间: 0.005244 秒
# 正在执行查询条件: ['12', '909', '7501']...
# 查询执行时间: 0.019207 秒
# 正在执行查询条件: ['7', '907', '7501']...
# 查询执行时间: 0.011553 秒
# 正在执行查询条件: ['5', '904', '7501']...
# 查询执行时间: 0.010306 秒
# 正在执行查询条件: ['3', '901', '7501']...
# 查询执行时间: 0.007014 秒
# 正在执行查询条件: ['3', '909', '7501']...
# 查询执行时间: 0.014860 秒
# 正在执行查询条件: ['9', '906', '7501']...
# 查询执行时间: 0.010951 秒
# 正在执行查询条件: ['8', '901', '7501']...
# 查询执行时间: 0.007325 秒
# 正在执行查询条件: ['2', '904', '7501']...
# 查询执行时间: 0.007597 秒
# 正在执行查询条件: ['8', '908', '7501']...
# 查询执行时间: 0.014549 秒
# 正在执行查询条件: ['9', '904', '7501']...
# 查询执行时间: 0.009426 秒
# 正在执行查询条件: ['14', '904', '7501']...
# 查询执行时间: 0.010182 秒
# 正在执行查询条件: ['8', '910', '7501']...
# 查询执行时间: 0.009644 秒
# 正在执行查询条件: ['9', '907', '7501']...
# 查询执行时间: 0.009881 秒
# 正在执行查询条件: ['14', '905', '7501']...
# 查询执行时间: 0.009373 秒
# 正在执行查询条件: ['2', '902', '7501']...
# 查询执行时间: 0.013041 秒
# 正在执行查询条件: ['7', '905', '7501']...
# 查询执行时间: 0.005817 秒
# 正在执行查询条件: ['5', '904', '7501']...
# 查询执行时间: 0.009443 秒
# 正在执行查询条件: ['1', '903', '7501']...
# 查询执行时间: 0.013333 秒
# 正在执行查询条件: ['4', '905', '7501']...
# 查询执行时间: 0.008639 秒
# 正在执行查询条件: ['12', '909', '7501']...
# 查询执行时间: 0.007037 秒
# 正在执行查询条件: ['12', '907', '7501']...
# 查询执行时间: 0.007469 秒
# 正在执行查询条件: ['1', '908', '7501']...
# 查询执行时间: 0.011147 秒
# 正在执行查询条件: ['10', '906', '7501']...
# 查询执行时间: 0.011733 秒
# 正在执行查询条件: ['9', '906', '7501']...
# 查询执行时间: 0.008966 秒
# 正在执行查询条件: ['5', '908', '7501']...
# 查询执行时间: 0.010458 秒
# 正在执行查询条件: ['1', '905', '7501']...
# 查询执行时间: 0.014492 秒
# 正在执行查询条件: ['12', '909', '7501']...
# 查询执行时间: 0.005318 秒
# 正在执行查询条件: ['9', '903', '7501']...
# 查询执行时间: 0.011515 秒
# 正在执行查询条件: ['13', '906', '7501']...
# 查询执行时间: 0.011890 秒
# 正在执行查询条件: ['11', '910', '7501']...
# 查询执行时间: 0.010710 秒
# 正在执行查询条件: ['12', '907', '7501']...
# 查询执行时间: 0.011968 秒
# 正在执行查询条件: ['11', '903', '7501']...
# 查询执行时间: 0.016007 秒
# 正在执行查询条件: ['10', '904', '7501']...
# 查询执行时间: 0.005113 秒
# 正在执行查询条件: ['14', '901', '7501']...
# 查询执行时间: 0.009924 秒
# 正在执行查询条件: ['14', '901', '7501']...
# 查询执行时间: 0.015518 秒
# 正在执行查询条件: ['7', '903', '7501']...
# 查询执行时间: 0.005810 秒
# 正在执行查询条件: ['15', '908', '7501']...
# 查询执行时间: 0.005915 秒
# 正在执行查询条件: ['4', '907', '7501']...
# 查询执行时间: 0.004720 秒
# 正在执行查询条件: ['13', '908', '7501']...
# 查询执行时间: 0.009914 秒
# 正在执行查询条件: ['1', '902', '7501']...
# 查询执行时间: 0.011240 秒
# 正在执行查询条件: ['1', '901', '7501']...
# 查询执行时间: 0.004076 秒
# 正在执行查询条件: ['4', '903', '7501']...
# 查询执行时间: 0.010697 秒

# %% [markdown]
# 4、脚本召回率测试

# %%
import numpy as np

def read_ivecs(fname):
    with open(fname, "rb") as f:
        data = []
        while True:
            try:
                # Read the dimension
                width = np.fromfile(f, 'int32', 1)[0]
                
                # Read the vector data
                vector = np.fromfile(f, 'int32', width)
                
                # If the vector is longer than 10, we only take the first 10 elements
                data.append(vector[:10])
            except IndexError:
                break  # End of file

    return np.array(data)

def read_output_file(fname):
    with open(fname, 'r') as f:
        lines = f.readlines()  # 读取所有行
        if len(lines) > 2:  # 如果文件行数大于2，忽略最后两行
            lines = lines[:-2]
        return [list(map(int, line.split())) for line in lines]

def extract_qps(fname):
    with open(fname, 'r') as f:
        lines = f.readlines()
        if lines:
            last_line = lines[-1].strip()  # 获取最后一行并去除首尾空格
            if "QPS:" in last_line:
                qps_value = last_line.split("QPS:")[-1].strip()  # 提取 QPS 值
                return qps_value
    return "N/A"  # 如果没有找到 QPS 值，返回 N/A

ROOT_DIR = os.path.abspath(os.path.join(os.getcwd(), "../../../data/Experiment"))
recall_file = os.path.join(os.getcwd(), "result", f"single_qps.out")

# 打开文件用于写入结果
with open(recall_file, "a") as output_file:
    list_1 = ["1", "3_1", "3_2", "3_3", "3_4", "4", "5_1", "5_2", "5_3", "5_4", "6", "7_1", "7_2", "7_3", "7_4"]
    list_2 = [86, 150, 250, 400]
    for i_value in list_1:
        for j_value in list_2:
            # Read ground truth
            gt_file = os.path.join(ROOT_DIR, f"labelfilterData/gt/enron/gt-query_set_{i_value}.ivecs")
            gt_data = read_ivecs(gt_file)

            # Read result file
            result_file = os.path.join(os.getcwd(), "result", f"{i_value}_16_200_{j_value}.out")
            result_data = read_output_file(result_file)

            # Extract QPS value
            qps_value = extract_qps(result_file)

            # Calculate recall
            total_queries = len(gt_data)
            correct_matches = 0

            # For each query in ground truth
            for i, gt_row in enumerate(gt_data):
                # Check if any of the first 10 elements from ground truth are in the result's top 10
                correct_matches += sum(1 for gt_val in gt_row if gt_val in result_data[i][:10])

            # Recall calculation
            recall = correct_matches / (total_queries * 10)  # Since each query has 10 elements to match

            # 写入结果到文件
            output_file.write(f"Recall Rate {i_value:<6} and {j_value:<4}: {recall:>6.4f}, QPS: {float(qps_value):>8.2f}\n")
